# %% [markdown]
# # 01 · 我的第一个 Python 程序
#
# | 项目 | 内容 |
# | --- | --- |
# | 姓名 | 旦知吉 |
# | 学号 | P251012384 |
# | 班级 | 25级新闻学4班 |
# | 日期 | 2026-09-24 |
#
# > 从上到下按 Shift+Enter 逐格运行。

# %%
print('Hello, Python!')
print('姓名：旦知吉')
print('学号：P251012384')
print('班级：25级新闻学4班')
print('课程：大数据与人工智能')
# Out:
# Hello, Python!
# 姓名：旦知吉
# 学号：P251012384
# 班级：25级新闻学4班
# 课程：大数据与人工智能

# %%
print('1 + 1 =', 1 + 1)
print('3 × 4 =', 3 * 4)
print('我叫', '旦知吉', '，来自', '25级新闻学4班')
# Out:
# 1 + 1 = 2
# 3 × 4 = 12
# 我叫 旦知吉 ，来自 25级新闻学4班
