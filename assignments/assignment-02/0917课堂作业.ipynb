# %% [markdown]
# # 0917 Python 课堂作业
#
# | 项目 | 内容 |
# | --- | --- |
# | 姓名 | 旦知吉 |
# | 学号 | P251012384 |
# | 班级 | 25级新闻学4班 |
# | 日期 | 2026-09-17 |
#
# > 提示：把上表和代码里的【】占位内容改成自己的信息，然后从上往下依次运行代码单元格（Shift+Enter），最后 Ctrl+S 保存提交。

# %% [markdown]
# ## 任务一：使用 print() 输出个人信息

# %%
# TODO：把下面三行【】里的内容改成你自己的信息，然后按 Shift+Enter 运行
print('姓名：旦知吉')
print('学号：P251012384')
print('班级：25级新闻学4班')
print('课程：大数据与人工智能')
print('日期：2026-09-17')

# %% [markdown]
# ## 任务二：print() 的小练习（加分项 · 选做）

# %%
# 1. 一次输出多项内容（逗号分隔，中间自动加空格）
print('我叫', '旦知吉', '，来自', '25级新闻学4班')

# 2. 用 sep 自定义分隔符
print('2026', '09', '17', sep='-')

# 3. 用 end 让两条 print 不换行
print('Hello', end=' ')
print('World!')
